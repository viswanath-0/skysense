# %%
import pandas as pd
import numpy as np
import sklearn

# %%
df = pd.read_csv(r"C:\Users\vishwa\Downloads\airline_passenger_satisfaction.csv")

# %%
df
# Out:
#         Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0                0   70172    Male     Loyal Customer   13  Personal Travel
# 1                1    5047    Male  disloyal Customer   25  Business travel
# 2                2  110028  Female     Loyal Customer   26  Business travel
# 3                3   24026  Female     Loyal Customer   25  Business travel
# 4                4  119299    Male     Loyal Customer   61  Business travel
# ...            ...     ...     ...                ...  ...              ...
# 129875       25971   78463    Male  disloyal Customer   34  Business travel
# 129876       25972   71167    Male     Loyal Customer   23  Business travel
# 129877       25973   37675  Female     Loyal Customer   17  Personal Travel
# 129878       25974   90086    Male     Loyal Customer   14  Business travel
# 129879       25975   34799  Female     Loyal Customer   42  Personal Travel
#
# ...

# %%
df.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %%
df.shape
# Out:
# (129880, 25)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
#        'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                             0
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# ...

# %%
df['Arrival Delay in Minutes'].fillna(0)
# Out:
# 0         18.0
# 1          6.0
# 2          0.0
# 3          9.0
# 4          0.0
#           ...
# 129875     0.0
# 129876     0.0
# 129877     0.0
# 129878     0.0
# 129879     0.0
# Name: Arrival Delay in Minutes, Length: 129880, dtype: float64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                             0
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# ...

# %%
df['Arrival Delay in Minutes'].fillna(0,inplace = True)
# Out:
# C:\Users\vishwa\AppData\Local\Temp\ipykernel_13324\1392030200.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Arrival Delay in Minutes'].fillna(0,inplace = True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                           0
# id                                   0
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# ...

# %%
for i in df:
    print("*"*10,i,"*"*10)
    print()
    print(df[i].unique())
    print()
# Out:
# ********** Unnamed: 0 **********
#
# [     0      1      2 ... 103901 103902 103903]
#
# ********** id **********
#
# [ 70172   5047 110028 ...  37675  90086  34799]
#
# ********** Gender **********
#
# ['Male' 'Female']
#
# ********** Customer Type **********
#
# ['Loyal Customer' 'disloyal Customer']
#
# ********** Age **********
#
# [13 25 26 61 47 52 41 20 24 12 53 33 45 38  9 17 43 58 23 57 49 36 22 31
#  15 35 67 37 40 34 39 50 29 54 21 28 27 69 60 48 59 46 30 66 64 44 51 32
#  19 42 16 11 62  8 56 68 55 18 65 72 70 63 10  7 14 80 74 71 85 73 76 77
#  75 79 78]
#
# ********** Type of Travel **********
#
# ['Personal Travel' 'Business travel']
#
# ********** Class **********
#
# ['Eco Plus' 'Business' 'Eco']
#
# ********** Flight Distance **********
#
# [ 460  235 1142 ... 1003 1441  884]
#
# ********** Inflight wifi service **********
#
# [3 2 4 1 5 0]
#
# ********** Departure/Arrival time convenient **********
#
# [4 2 5 3 1 0]
#
# ********** Ease of Online booking **********
# ...

# %%
count =0
for i in df:
    if " " or "" in df[i]:
        count+=1

# %%
count
# Out:
# 25

# %%
# Replace empty strings and whitespace-only strings with NaN across the whole DataFrame
df = df.replace(r'^\s*$', np.nan, regex=True)

# Now check missing values properly
print(df.isnull().sum())
# Out:
# Unnamed: 0                           0
# id                                   0
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# ...

# %%
count =0
for i in df:
    if " " or "" in df[i]:
        count+=1

# %%
count
# Out:
# 25

# %%
for i in df:
    if df[i] == " ":
        df[i].replace(" ",np.nan)
    elif df[i] =="":
        df[i].replace("",np.nan)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13324\3095525434.py in ?()
#       1 for i in df:
# ----> 2     if df[i] == " ":
#       3         df[i].replace(" ",np.nan)
#       4     elif df[i] =="":
#       5         df[i].replace("",np.nan)
#
# ~\.conda\envs\batch433\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
import numpy as np

for i in df.columns:
    df[i] = df[i].replace(" ", np.nan)
    df[i] = df[i].replace("", np.nan)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                           0
# id                                   0
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# ...

# %%
count =0
for i in df:
    if " " in df[i]:
        count+=1

# %%
count
# Out:
# 0

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, id, Gender, Customer Type, Age, Type of Travel, Class, Flight Distance, Inflight wifi service, Departure/Arrival time convenient, Ease of Online booking, Gate location, Food and drink, Online boarding, Seat comfort, Inflight entertainment, On-board service, Leg room service, Baggage handling, Checkin service, Inflight service, Cleanliness, Departure Delay in Minutes, Arrival Delay in Minutes, satisfaction]
# Index: []
#
# [0 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
#        'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
df.head(2)
# Out:
#    Unnamed: 0     id Gender      Customer Type  Age   Type of Travel  \
# 0           0  70172   Male     Loyal Customer   13  Personal Travel
# 1           1   5047   Male  disloyal Customer   25  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# ...

# %% [markdown]
# # Spliting the Data X[inputs] & y[target variable]

# %%
X = df.drop(['Unnamed: 0', 'id','satisfaction'], axis=1)

# %%
X.head()
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
# 3  Female     Loyal Customer   25  Business travel  Business              562
# 4    Male     Loyal Customer   61  Business travel  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Seat comfort  \
# 0                       3              1  ...             5
# ...

# %%
y = df[['satisfaction']]

# %%
y.head()
# Out:
#               satisfaction
# 0  neutral or dissatisfied
# 1  neutral or dissatisfied
# 2                satisfied
# 3  neutral or dissatisfied
# 4                satisfied

# %% [markdown]
# # Seperation of train and test data

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.8,random_state = 42)

# %%
X_train
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 21413   Female     Loyal Customer   64  Personal Travel  Business
# 7284      Male  disloyal Customer   26  Business travel  Business
# 86080   Female     Loyal Customer    8  Personal Travel       Eco
# 59842     Male     Loyal Customer   41  Business travel  Business
# 69486   Female  disloyal Customer   19  Business travel       Eco
# ...        ...                ...  ...              ...       ...
# 128106  Female     Loyal Customer   38  Business travel       Eco
# 103694    Male     Loyal Customer   46  Business travel       Eco
# 860     Female     Loyal Customer   37  Business travel       Eco
# 15795   Female     Loyal Customer   14  Personal Travel       Eco
# 121958    Male     Loyal Customer   34  Business travel       Eco
#
#         Flight Distance  Inflight wifi service  \
# 21413               965                      3
# 7284                592                      2
# ...

# %%
X_test
# Out:
#         Gender   Customer Type  Age   Type of Travel     Class  \
# 103044    Male  Loyal Customer   66  Personal Travel       Eco
# 43282   Female  Loyal Customer   38  Business travel  Business
# 65543   Female  Loyal Customer   38  Business travel       Eco
# 65083   Female  Loyal Customer   32  Personal Travel       Eco
# 76496     Male  Loyal Customer   33  Business travel  Business
# ...        ...             ...  ...              ...       ...
# 121239  Female  Loyal Customer   44  Personal Travel       Eco
# 6010    Female  Loyal Customer   53  Business travel  Business
# 101127    Male  Loyal Customer   28  Business travel  Eco Plus
# 82323     Male  Loyal Customer   30  Business travel  Business
# 61871   Female  Loyal Customer   59  Personal Travel       Eco
#
#         Flight Distance  Inflight wifi service  \
# 103044             1678                      3
# 43282               954                      2
# 65543               189                      2
# ...

# %%
y_train
# Out:
#                    satisfaction
# 21413   neutral or dissatisfied
# 7284    neutral or dissatisfied
# 86080   neutral or dissatisfied
# 59842                 satisfied
# 69486   neutral or dissatisfied
# ...                         ...
# 128106                satisfied
# 103694  neutral or dissatisfied
# 860                   satisfied
# 15795   neutral or dissatisfied
# 121958  neutral or dissatisfied
#
# [103904 rows x 1 columns]

# %%
y_test
# Out:
#                    satisfaction
# 103044  neutral or dissatisfied
# 43282                 satisfied
# 65543   neutral or dissatisfied
# 65083   neutral or dissatisfied
# 76496                 satisfied
# ...                         ...
# 121239  neutral or dissatisfied
# 6010                  satisfied
# 101127                satisfied
# 82323                 satisfied
# 61871   neutral or dissatisfied
#
# [25976 rows x 1 columns]

# %%
cat_df = X_train[['Gender','Customer Type','Type of Travel']]

# %%
cat_df
# Out:
#         Gender      Customer Type   Type of Travel
# 21413   Female     Loyal Customer  Personal Travel
# 7284      Male  disloyal Customer  Business travel
# 86080   Female     Loyal Customer  Personal Travel
# 59842     Male     Loyal Customer  Business travel
# 69486   Female  disloyal Customer  Business travel
# ...        ...                ...              ...
# 128106  Female     Loyal Customer  Business travel
# 103694    Male     Loyal Customer  Business travel
# 860     Female     Loyal Customer  Business travel
# 15795   Female     Loyal Customer  Personal Travel
# 121958    Male     Loyal Customer  Business travel
#
# [103904 rows x 3 columns]

# %%
cato_df = X_train[['Class']]

# %%
cato_df
# Out:
#            Class
# 21413   Business
# 7284    Business
# 86080        Eco
# 59842   Business
# 69486        Eco
# ...          ...
# 128106       Eco
# 103694       Eco
# 860          Eco
# 15795        Eco
# 121958       Eco
#
# [103904 rows x 1 columns]

# %%
num_df = X_train.select_dtypes(include = 'number')

# %%
num_df
# Out:
#         Age  Flight Distance  Inflight wifi service  \
# 21413    64              965                      3
# 7284     26              592                      2
# 86080     8              993                      3
# 59842    41             2223                      4
# 69486    19             1235                      4
# ...     ...              ...                    ...
# 128106   38              907                      4
# 103694   46             1197                      1
# 860      37              320                      5
# 15795    14              351                      4
# 121958   34              867                      2
#
#         Departure/Arrival time convenient  Ease of Online booking  \
# 21413                                   5                       3
# 7284                                    1                       1
# 86080                                   4                       3
# 59842                                   4                       4
# ...

# %%
for i in num_df:
    print("*"*10,i,"*"*10)
    print()
    print(num_df[i].unique())
    print()
# Out:
# ********** Age **********
#
# [64 26  8 41 19 47 40 18 38 24 29 35 45 60 62 49 39 27 37 22 57 61 42 46
#  65 52 17 50 20 66 36 30 23 55 43 67  9 58 25 34 44 54 28 15 21 69 12 56
#  48 13 51  7 59 31 70 77 16 80 85 33 32 11 72 53 10 63 14 68 75 71 73 76
#  78 74 79]
#
# ********** Flight Distance **********
#
# [ 965  592  993 ... 1441 1343  905]
#
# ********** Inflight wifi service **********
#
# [3 2 4 5 1 0]
#
# ********** Departure/Arrival time convenient **********
#
# [5 1 4 3 2 0]
#
# ********** Ease of Online booking **********
#
# [3 1 4 2 5 0]
#
# ********** Gate location **********
#
# [3 2 1 4 5 0]
#
# ********** Food and drink **********
#
# [5 3 4 1 2 0]
#
# ********** Online boarding **********
#
# [5 1 3 2 4 0]
#
# ********** Seat comfort **********
#
# [5 3 4 2 1 0]
#
# ********** Inflight entertainment **********
#
# [1 3 4 5 2 0]
#
# ********** On-board service **********
#
# [1 5 4 2 3 0]
#
# ********** Leg room service **********
#
# [3 4 5 2 1 0]
#
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
OHE = OneHotEncoder(sparse_output=False).set_output(transform = 'pandas')
cat_df_trans = OHE.fit_transform(cat_df)

# %%
cat_df_trans
# Out:
#         Gender_Female  Gender_Male  Customer Type_Loyal Customer  \
# 21413             1.0          0.0                           1.0
# 7284              0.0          1.0                           0.0
# 86080             1.0          0.0                           1.0
# 59842             0.0          1.0                           1.0
# 69486             1.0          0.0                           0.0
# ...               ...          ...                           ...
# 128106            1.0          0.0                           1.0
# 103694            0.0          1.0                           1.0
# 860               1.0          0.0                           1.0
# 15795             1.0          0.0                           1.0
# 121958            0.0          1.0                           1.0
#
#         Customer Type_disloyal Customer  Type of Travel_Business travel  \
# 21413                               0.0                             0.0
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
OE = OrdinalEncoder().set_output(transform='pandas')
cato_df_trans  = OE.fit_transform(cato_df)

# %%
cato_df_trans
# Out:
#         Class
# 21413     0.0
# 7284      0.0
# 86080     1.0
# 59842     0.0
# 69486     1.0
# ...       ...
# 128106    1.0
# 103694    1.0
# 860       1.0
# 15795     1.0
# 121958    1.0
#
# [103904 rows x 1 columns]

# %%
from sklearn.preprocessing import StandardScaler

STD = StandardScaler().set_output(transform = 'pandas')

num_df_trans = STD.fit_transform(num_df)

# %%
num_df_trans
# Out:
#              Age  Flight Distance  Inflight wifi service  \
# 21413   1.626500        -0.224186               0.206148
# 7284   -0.886203        -0.598714              -0.545787
# 86080  -2.076430        -0.196071               0.206148
# 59842   0.105653         1.038969               0.958084
# 69486  -1.349069         0.046920               0.958084
# ...          ...              ...                    ...
# 128106 -0.092718        -0.282424               0.958084
# 103694  0.436272         0.008765              -1.297723
# 860    -0.158842        -0.871829               1.710020
# 15795  -1.679688        -0.840702               0.958084
# 121958 -0.357213        -0.322588              -0.545787
#
#         Departure/Arrival time convenient  Ease of Online booking  \
# 21413                            1.271199                0.174602
# 7284                            -1.349410               -1.250971
# 86080                            0.616046                0.174602
# ...

# %%
cat_df_trans.reset_index(inplace = True)

# %%
cato_df_trans.reset_index(inplace = True)

# %%
num_df_trans.reset_index(inplace = True)

# %%
X_train_trans = pd.concat([cat_df_trans,cato_df_trans,num_df_trans],axis=1)

# %%
X_train_trans
# Out:
#          index  Gender_Female  Gender_Male  Customer Type_Loyal Customer  \
# 0        21413            1.0          0.0                           1.0
# 1         7284            0.0          1.0                           0.0
# 2        86080            1.0          0.0                           1.0
# 3        59842            0.0          1.0                           1.0
# 4        69486            1.0          0.0                           0.0
# ...        ...            ...          ...                           ...
# 103899  128106            1.0          0.0                           1.0
# 103900  103694            0.0          1.0                           1.0
# 103901     860            1.0          0.0                           1.0
# 103902   15795            1.0          0.0                           1.0
# 103903  121958            0.0          1.0                           1.0
#
#         Customer Type_disloyal Customer  Type of Travel_Business travel  \
# ...

# %%
X_train_trans.pop('index')
# Out:
#          index   index   index
# 0        21413   21413   21413
# 1         7284    7284    7284
# 2        86080   86080   86080
# 3        59842   59842   59842
# 4        69486   69486   69486
# ...        ...     ...     ...
# 103899  128106  128106  128106
# 103900  103694  103694  103694
# 103901     860     860     860
# 103902   15795   15795   15795
# 103903  121958  121958  121958
#
# [103904 rows x 3 columns]

# %%
from sklearn.preprocessing import LabelEncoder

LE = LabelEncoder()

y_train_trans = LE.fit_transform(y_train)
# Out:
# C:\Users\vishwa\.conda\envs\batch433\Lib\site-packages\sklearn\preprocessing\_label.py:120: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_train_trans
# Out:
# array([0, 0, 0, ..., 1, 0, 0], shape=(103904,))

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

LE = LabelEncoder()

y_train_trans = pd.DataFrame(
    LE.fit_transform(y_train),
    index=y_train.index   # keeps the original row indices aligned
)
# Out:
# C:\Users\vishwa\.conda\envs\batch433\Lib\site-packages\sklearn\preprocessing\_label.py:120: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_train_trans
# Out:
#         0
# 21413   0
# 7284    0
# 86080   0
# 59842   1
# 69486   0
# ...    ..
# 128106  1
# 103694  0
# 860     1
# 15795   0
# 121958  0
#
# [103904 rows x 1 columns]

# %%
y_train_trans.reset_index(inplace = True)

# %%
y_train_trans
# Out:
#          index  0
# 0        21413  0
# 1         7284  0
# 2        86080  0
# 3        59842  1
# 4        69486  0
# ...        ... ..
# 103899  128106  1
# 103900  103694  0
# 103901     860  1
# 103902   15795  0
# 103903  121958  0
#
# [103904 rows x 2 columns]

# %%
y_train_trans.pop('index')
# Out:
# 0          21413
# 1           7284
# 2          86080
# 3          59842
# 4          69486
#            ...
# 103899    128106
# 103900    103694
# 103901       860
# 103902     15795
# 103903    121958
# Name: index, Length: 103904, dtype: int64

# %%
cat_df = X_test[['Gender','Customer Type','Type of Travel']]

# %%
cato_df = X_test[['Class']]

# %%
num_df = X_test.select_dtypes(include = 'number')

# %%
cat_df
# Out:
#         Gender   Customer Type   Type of Travel
# 103044    Male  Loyal Customer  Personal Travel
# 43282   Female  Loyal Customer  Business travel
# 65543   Female  Loyal Customer  Business travel
# 65083   Female  Loyal Customer  Personal Travel
# 76496     Male  Loyal Customer  Business travel
# ...        ...             ...              ...
# 121239  Female  Loyal Customer  Personal Travel
# 6010    Female  Loyal Customer  Business travel
# 101127    Male  Loyal Customer  Business travel
# 82323     Male  Loyal Customer  Business travel
# 61871   Female  Loyal Customer  Personal Travel
#
# [25976 rows x 3 columns]

# %%
cato_df
# Out:
#            Class
# 103044       Eco
# 43282   Business
# 65543        Eco
# 65083        Eco
# 76496   Business
# ...          ...
# 121239       Eco
# 6010    Business
# 101127  Eco Plus
# 82323   Business
# 61871        Eco
#
# [25976 rows x 1 columns]

# %%
num_df
# Out:
#         Age  Flight Distance  Inflight wifi service  \
# 103044   66             1678                      3
# 43282    38              954                      2
# 65543    38              189                      2
# 65083    32              175                      2
# 76496    33             1990                      5
# ...     ...              ...                    ...
# 121239   44              264                      4
# 6010     53             2248                      5
# 101127   28              489                      4
# 82323    30              448                      2
# 61871    59             1721                      3
#
#         Departure/Arrival time convenient  Ease of Online booking  \
# 103044                                  2                       3
# 43282                                   2                       2
# 65543                                   1                       1
# 65083                                   5                       2
# ...

# %%
cat_df_trans = OHE.transform(cat_df)

# %%
cato_df_trans = OE.transform(cato_df)

# %%
num_df_trans = STD.transform(num_df)

# %%
cat_df_trans.reset_index(inplace = True)

# %%
cato_df_trans.reset_index(inplace = True)

# %%
num_df_trans.reset_index(inplace = True)

# %%
cat_df_trans
# Out:
#         index  Gender_Female  Gender_Male  Customer Type_Loyal Customer  \
# 0      103044            0.0          1.0                           1.0
# 1       43282            1.0          0.0                           1.0
# 2       65543            1.0          0.0                           1.0
# 3       65083            1.0          0.0                           1.0
# 4       76496            0.0          1.0                           1.0
# ...       ...            ...          ...                           ...
# 25971  121239            1.0          0.0                           1.0
# 25972    6010            1.0          0.0                           1.0
# 25973  101127            0.0          1.0                           1.0
# 25974   82323            0.0          1.0                           1.0
# 25975   61871            1.0          0.0                           1.0
#
#        Customer Type_disloyal Customer  Type of Travel_Business travel  \
# ...

# %%
cato_df_trans
# Out:
#         index  Class
# 0      103044    1.0
# 1       43282    0.0
# 2       65543    1.0
# 3       65083    1.0
# 4       76496    0.0
# ...       ...    ...
# 25971  121239    1.0
# 25972    6010    0.0
# 25973  101127    2.0
# 25974   82323    0.0
# 25975   61871    1.0
#
# [25976 rows x 2 columns]

# %%
num_df_trans
# Out:
#         index       Age  Flight Distance  Inflight wifi service  \
# 0      103044  1.758747         0.491735               0.206148
# 1       43282 -0.092718        -0.235231              -0.545787
# 2       65543 -0.092718        -1.003366              -0.545787
# 3       65083 -0.489460        -1.017423              -0.545787
# 4       76496 -0.423337         0.805014               1.710020
# ...       ...       ...              ...                    ...
# 25971  121239  0.304025        -0.928058               0.958084
# 25972    6010  0.899138         1.064071               1.710020
# 25973  101127 -0.753955        -0.702136               0.958084
# 25974   82323 -0.621708        -0.743304              -0.545787
# 25975   61871  1.295881         0.534912               0.206148
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# 0                              -0.694258                0.174602
# ...

# %%
X_test_trans = pd.concat([cat_df_trans,cato_df_trans,num_df_trans],axis=1)

# %%
X_test_trans
# Out:
#         index  Gender_Female  Gender_Male  Customer Type_Loyal Customer  \
# 0      103044            0.0          1.0                           1.0
# 1       43282            1.0          0.0                           1.0
# 2       65543            1.0          0.0                           1.0
# 3       65083            1.0          0.0                           1.0
# 4       76496            0.0          1.0                           1.0
# ...       ...            ...          ...                           ...
# 25971  121239            1.0          0.0                           1.0
# 25972    6010            1.0          0.0                           1.0
# 25973  101127            0.0          1.0                           1.0
# 25974   82323            0.0          1.0                           1.0
# 25975   61871            1.0          0.0                           1.0
#
#        Customer Type_disloyal Customer  Type of Travel_Business travel  \
# ...

# %%
X_test_trans.pop('index')
# Out:
#         index   index   index
# 0      103044  103044  103044
# 1       43282   43282   43282
# 2       65543   65543   65543
# 3       65083   65083   65083
# 4       76496   76496   76496
# ...       ...     ...     ...
# 25971  121239  121239  121239
# 25972    6010    6010    6010
# 25973  101127  101127  101127
# 25974   82323   82323   82323
# 25975   61871   61871   61871
#
# [25976 rows x 3 columns]

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier()

model.fit(X_train_trans,y_train_trans)
# Out:
# C:\Users\vishwa\.conda\envs\batch433\Lib\site-packages\sklearn\neighbors\_classification.py:243: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
import pandas as pd

y_pred = model.predict(X_test_trans)

y_pred = pd.DataFrame(
    y_pred,
    columns=['Prediction']
)

y_pred
# Out:
#        Prediction
# 0               0
# 1               1
# 2               0
# 3               0
# 4               1
# ...           ...
# 25971           0
# 25972           1
# 25973           1
# 25974           1
# 25975           0
#
# [25976 rows x 1 columns]

# %%
y_test_trans = LE.transform(y_test)
# Out:
# C:\Users\vishwa\.conda\envs\batch433\Lib\site-packages\sklearn\preprocessing\_label.py:139: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)

# %%
y_test_trans
# Out:
# array([0, 1, 0, ..., 1, 1, 0], shape=(25976,))

# %%
import pandas as pd

y_test_trans = LE.transform(y_test)

y_test_trans = pd.DataFrame(y_test_trans, columns=['target_encoded'])

y_test_trans
# Out:
# C:\Users\vishwa\.conda\envs\batch433\Lib\site-packages\sklearn\preprocessing\_label.py:139: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
#        target_encoded
# 0                   0
# 1                   1
# 2                   0
# 3                   0
# 4                   1
# ...               ...
# 25971               0
# 25972               1
# 25973               1
# 25974               1
# 25975               0
#
# [25976 rows x 1 columns]

# %%
## How to save your production file
import joblib

joblib.dump({'model':model,'cat_encod':OHE,'cato_encod':OE,'output_encod':LE,'num_encod':STD},'model_prod1323_file.pkl')
# Out:
# ['model_prod1323_file.pkl']

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test_trans, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94     14622
#            1       0.95      0.89      0.92     11354
#
#     accuracy                           0.93     25976
#    macro avg       0.93      0.92      0.93     25976
# weighted avg       0.93      0.93      0.93     25976
